# %%
import wp_src_code_12_31 as wp

import cv2, math, os, random
import numpy as np
import matplotlib.pyplot as plt

# %%
# use image samples for demontration
ori = cv2.imread('/home/yig319/Dropbox/wallpaper_group_generator/Original_images/dog-park.png') 
image1 = np.copy(ori) # load image used to crop and transform
image1 = np.array(ori)
imgplot = plt.imshow(image1)

# %%
type(ori)
# Out:
# numpy.ndarray

# %%
image1 = np.array(ori)
type(image1)
# Out:
# numpy.ndarray

# %% [markdown]
# # p1 symmetry:

# %%
#set output image size 
width, height = (256, 256)

# use random size and angle as croped part of image
angle = random.randint(30,85)
unit_h = random.randint(20,80)
lower_bound_w = int(unit_h/math.tan(math.radians(angle)))
if lower_bound_w > 65:
    unit_w = random.randint(lower_bound_w+15, lower_bound_w+75)
else: 
    unit_w = random.randint(lower_bound_w+15, 85)

# width, length, angle of unit cell:
unit_w, unit_h, angle
# Out:
# (74, 54, 43)

# %%
p1_1 = wp.p1_rectangular(image1,unit_w,unit_h,width,height)
p1_2 = wp.p1_square(image1,unit_w,width,height)
p1_3 = wp.p1_oblique(image1,unit_w*2,unit_h,angle,width,height) 
p1_4 = wp.p1_hexagonal(image1,unit_w*2,width,height)
p1_5 = wp.p1_rhombic(image1,unit_w,unit_h,width,height)

# %%
plt.figure(figsize=(18, 3))
plt.subplot(151)
plt.imshow(p1_1)
plt.subplot(152)
plt.imshow(p1_2)
plt.subplot(153)
plt.imshow(p1_3)
plt.subplot(154)
plt.imshow(p1_4)
plt.subplot(155)
plt.imshow(p1_5)
plt.suptitle('p1 symmetry Plotting')
plt.show()

# %% [markdown]
# # p2 symmetry:

# %%
#set output image size 
width, height = (256, 256)

# use random size and angle as croped part of image
angle = random.randint(30,85)
unit_h = random.randint(20,80)
lower_bound_w = int(unit_h/math.tan(math.radians(angle)))
if lower_bound_w > 65:
    unit_w = random.randint(lower_bound_w+15, lower_bound_w+75)
else: 
    unit_w = random.randint(lower_bound_w+15, 85)

# width, length, angle of unit cell:
unit_w, unit_h, angle
# Out:
# (77, 21, 30)

# %%
p2_1 = wp.p2_rectangular(image1,unit_w,unit_h,width,height)
p2_2 = wp.p2_square(image1,unit_w,width,height)
p2_3 = wp.p2_oblique(image1,unit_w*2,unit_h,angle,width,height) 
p2_4 = wp.p2_hexagonal(image1,unit_w*2,width,height)
p2_5 = wp.p2_rhombic(image1,unit_w,unit_h,width,height)

# %%
plt.figure(figsize=(18, 3))
plt.subplot(151)
plt.imshow(p2_1)
plt.subplot(152)
plt.imshow(p2_2)
plt.subplot(153)
plt.imshow(p2_3)
plt.subplot(154)
plt.imshow(p2_4)
plt.subplot(155)
plt.imshow(p2_5)
plt.suptitle('p2 symmetry Plotting')
plt.show()

# %% [markdown]
# # pm

# %%
#set output image size 
width, height = (256, 256)

# use random size and angle as croped part of image
angle = random.randint(30,85)
unit_h = random.randint(20,80)
lower_bound_w = int(unit_h/math.tan(math.radians(angle)))
if lower_bound_w > 65:
    unit_w = random.randint(lower_bound_w+15, lower_bound_w+75)
else: 
    unit_w = random.randint(lower_bound_w+15, 85)

# width, length, angle of unit cell:
unit_w, unit_h, angle
# Out:
# (78, 48, 67)

# %%
pm_1 = wp.pm_horizontal(image1,unit_w,unit_h,width,height)
pm_2 = wp.pm_vertical(image1,unit_w,unit_h,width,height)

# %%
plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.imshow(p2_1)
plt.subplot(122)
plt.imshow(p2_2)

plt.suptitle('pm symmetry Plotting')
plt.show()

# %% [markdown]
# # pg

# %%
#set output image size 
width, height = (256, 256)

# use random size and angle as croped part of image
angle = random.randint(30,85)
unit_h = random.randint(20,80)
lower_bound_w = int(unit_h/math.tan(math.radians(angle)))
if lower_bound_w > 65:
    unit_w = random.randint(lower_bound_w+15, lower_bound_w+75)
else: 
    unit_w = random.randint(lower_bound_w+15, 85)

# width, length, angle of unit cell:
unit_w, unit_h, angle
# Out:
# (57, 55, 74)

# %%
pg_1 = wp.pg_horizontal(image1,unit_w,unit_h,width,height) 
pg_2 = wp.pg_vertical(image1,unit_w,unit_h,width,height)

# %%
plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.imshow(pg_1)
plt.subplot(122)
plt.imshow(pg_2)

plt.suptitle('pg symmetry Plotting')
plt.show()

# %% [markdown]
# # pmm:

# %%
#set output image size 
width, height = (256, 256)

# use random size and angle as croped part of image
angle = random.randint(30,85)
unit_h = random.randint(20,80)
lower_bound_w = int(unit_h/math.tan(math.radians(angle)))
if lower_bound_w > 65:
    unit_w = random.randint(lower_bound_w+15, lower_bound_w+75)
else: 
    unit_w = random.randint(lower_bound_w+15, 85)

# width, length, angle of unit cell:
unit_w, unit_h, angle
# Out:
# (68, 60, 58)

# %%
pmm_1 = wp.pmm(image1,unit_w,unit_h,width,height)

# %%
plt.figure(figsize=(5, 5))
plt.imshow(pmm_1)
plt.title('pmm symmetry Plotting')
# Out:
# Text(0.5, 1.0, 'pmm symmetry Plotting')

# %% [markdown]
# # pmg

# %%
#set output image size 
width, height = (256, 256)

# use random size and angle as croped part of image
angle = random.randint(30,85)
unit_h = random.randint(20,80)
lower_bound_w = int(unit_h/math.tan(math.radians(angle)))
if lower_bound_w > 65:
    unit_w = random.randint(lower_bound_w+15, lower_bound_w+75)
else: 
    unit_w = random.randint(lower_bound_w+15, 85)

# width, length, angle of unit cell:
unit_w, unit_h, angle
# Out:
# (79, 38, 49)

# %%
pmg_1 = wp.pmg_horizontal(image1,unit_w,unit_h,width,height)
pmg_2 = wp.pmg_vertical(image1,unit_w,unit_h,width,height)

# %%
plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.imshow(pmg_1)
plt.subplot(122)
plt.imshow(pmg_2)

plt.suptitle('pmg symmetry Plotting')
plt.show()

# %% [markdown]
# # cm

# %%
#set output image size 
width, height = (256, 256)

# use random size and angle as croped part of image
angle = random.randint(30,85)
unit_h = random.randint(20,80)
lower_bound_w = int(unit_h/math.tan(math.radians(angle)))
if lower_bound_w > 65:
    unit_w = random.randint(lower_bound_w+15, lower_bound_w+75)
else: 
    unit_w = random.randint(lower_bound_w+15, 85)

# width, length, angle of unit cell:
unit_w, unit_h, angle
# Out:
# (44, 32, 73)

# %%
cm_1 = wp.cm_horizontal(image1,unit_w,unit_h,width,height)
cm_2 = wp.cm_vertical(image1,unit_w,unit_h,width,height)

# %%
plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.imshow(cm_1)
plt.subplot(122)
plt.imshow(cm_2)
plt.suptitle('cm symmetry Plotting')
plt.show()

# %% [markdown]
# # pgg

# %%
#set output image size 
width, height = (256, 256)

# use random size and angle as croped part of image
angle = random.randint(30,85)
unit_h = random.randint(20,80)
lower_bound_w = int(unit_h/math.tan(math.radians(angle)))
if lower_bound_w > 65:
    unit_w = random.randint(lower_bound_w+15, lower_bound_w+75)
else: 
    unit_w = random.randint(lower_bound_w+15, 85)

# width, length, angle of unit cell:
unit_w, unit_h, angle
# Out:
# (84, 22, 51)

# %%
pgg_1 = wp.pgg(image1,unit_w,unit_h,width,height)

# %%
plt.figure(figsize=(5, 5))
plt.imshow(pgg_1)
plt.title('pgg symmetry Plotting')
# Out:
# Text(0.5, 1.0, 'pgg symmetry Plotting')

# %% [markdown]
# # cmm

# %%
#set output image size 
width, height = (256, 256)

# use random size and angle as croped part of image
angle = random.randint(30,85)
unit_h = random.randint(20,80)
lower_bound_w = int(unit_h/math.tan(math.radians(angle)))
if lower_bound_w > 65:
    unit_w = random.randint(lower_bound_w+15, lower_bound_w+75)
else: 
    unit_w = random.randint(lower_bound_w+15, 85)

# width, length, angle of unit cell:
unit_w, unit_h, angle
# Out:
# (57, 63, 66)

# %%
cmm_1 = wp.cmm(image1,unit_w,unit_h,width,height)

plt.figure(figsize=(5, 5))
plt.imshow(cmm_1)
plt.title('cmm symmetry Plotting')
# Out:
# Text(0.5, 1.0, 'cmm symmetry Plotting')

# %% [markdown]
# # p4

# %%
#set output image size 
width, height = (256, 256)

# use random size and angle as croped part of image
angle = random.randint(30,85)
unit_h = random.randint(20,80)
lower_bound_w = int(unit_h/math.tan(math.radians(angle)))
if lower_bound_w > 65:
    unit_w = random.randint(lower_bound_w+15, lower_bound_w+75)
else: 
    unit_w = random.randint(lower_bound_w+15, 85)

# width, length, angle of unit cell:
unit_w, unit_h, angle
# Out:
# (134, 65, 36)

# %%
p4_1 = wp.p4(image1,unit_w,width,height)

plt.figure(figsize=(5, 5))
plt.imshow(p4_1)
plt.title('p4 symmetry Plotting')
# Out:
# Text(0.5, 1.0, 'p4 symmetry Plotting')

# %% [markdown]
# # p4m

# %%
#set output image size 
width, height = (256, 256)

# use random size and angle as croped part of image
angle = random.randint(30,85)
unit_h = random.randint(20,80)
lower_bound_w = int(unit_h/math.tan(math.radians(angle)))
if lower_bound_w > 65:
    unit_w = random.randint(lower_bound_w+15, lower_bound_w+75)
else: 
    unit_w = random.randint(lower_bound_w+15, 85)

# width, length, angle of unit cell:
unit_w, unit_h, angle
# Out:
# (61, 74, 80)

# %%
p4m_1 = wp.p4m(image1,unit_w,width,height) 

plt.figure(figsize=(5, 5))
plt.imshow(p4m_1)
plt.title('p4m symmetry Plotting')
# Out:
# Text(0.5, 1.0, 'p4m symmetry Plotting')

# %% [markdown]
# # p4g

# %%
#set output image size 
width, height = (256, 256)

# use random size and angle as croped part of image
angle = random.randint(30,85)
unit_h = random.randint(20,80)
lower_bound_w = int(unit_h/math.tan(math.radians(angle)))
if lower_bound_w > 65:
    unit_w = random.randint(lower_bound_w+15, lower_bound_w+75)
else: 
    unit_w = random.randint(lower_bound_w+15, 85)

# width, length, angle of unit cell:
unit_w, unit_h, angle
# Out:
# (64, 60, 69)

# %%
p4g_1 = wp.p4g(image1,unit_w,width,height) 

plt.figure(figsize=(5, 5))
plt.imshow(p4g_1)
plt.title('p4g symmetry Plotting')
# Out:
# Text(0.5, 1.0, 'p4g symmetry Plotting')

# %% [markdown]
# # p3

# %%
#set output image size 
width, height = (256, 256)

# use random size and angle as croped part of image
angle = random.randint(30,85)
unit_h = random.randint(20,80)
lower_bound_w = int(unit_h/math.tan(math.radians(angle)))
if lower_bound_w > 65:
    unit_w = random.randint(lower_bound_w+15, lower_bound_w+75)
else: 
    unit_w = random.randint(lower_bound_w+15, 85)

# width, length, angle of unit cell:
unit_w, unit_h, angle
# Out:
# (136, 68, 32)

# %%
p3_1 = wp.p3(image1,unit_w,width,height) 

plt.figure(figsize=(5, 5))
plt.imshow(p3_1)
plt.title('p3 symmetry Plotting')
# Out:
# Text(0.5, 1.0, 'p3 symmetry Plotting')

# %% [markdown]
# # p3m1

# %%
#set output image size 
width, height = (256, 256)

# use random size and angle as croped part of image
angle = random.randint(30,85)
unit_h = random.randint(20,80)
lower_bound_w = int(unit_h/math.tan(math.radians(angle)))
if lower_bound_w > 65:
    unit_w = random.randint(lower_bound_w+15, lower_bound_w+75)
else: 
    unit_w = random.randint(lower_bound_w+15, 85)

# width, length, angle of unit cell:
unit_w, unit_h, angle
# Out:
# (51, 70, 75)

# %%
p3m1_1 = wp.p31m(image1,unit_w,width,height)

plt.figure(figsize=(5, 5))
plt.imshow(p3m1_1)
plt.title('p3m1 symmetry Plotting')
# Out:
# Text(0.5, 1.0, 'p3m1 symmetry Plotting')

# %% [markdown]
# # p31m

# %%
#set output image size 
width, height = (256, 256)

# use random size and angle as croped part of image
angle = random.randint(30,85)
unit_h = random.randint(20,80)
lower_bound_w = int(unit_h/math.tan(math.radians(angle)))
if lower_bound_w > 65:
    unit_w = random.randint(lower_bound_w+15, lower_bound_w+75)
else: 
    unit_w = random.randint(lower_bound_w+15, 85)

# width, length, angle of unit cell:
unit_w, unit_h, angle
# Out:
# (60, 69, 61)

# %%
p31m_1 = wp.p31m(image1,unit_w,width,height)

plt.figure(figsize=(5, 5))
plt.imshow(p31m_1)
plt.title('p31m symmetry Plotting')
# Out:
# Text(0.5, 1.0, 'p31m symmetry Plotting')

# %% [markdown]
# # p6

# %%
#set output image size 
width, height = (256, 256)

# use random size and angle as croped part of image
angle = random.randint(30,85)
unit_h = random.randint(20,80)
lower_bound_w = int(unit_h/math.tan(math.radians(angle)))
if lower_bound_w > 65:
    unit_w = random.randint(lower_bound_w+15, lower_bound_w+75)
else: 
    unit_w = random.randint(lower_bound_w+15, 85)

# width, length, angle of unit cell:
unit_w, unit_h, angle
# Out:
# (84, 72, 51)

# %%
p6_1 = wp.p6(image1,unit_w,width,height)

plt.figure(figsize=(5, 5))
plt.imshow(p6_1)
plt.title('p6_1 symmetry Plotting')
# Out:
# Text(0.5, 1.0, 'p6_1 symmetry Plotting')

# %% [markdown]
# # p6m

# %%
#set output image size 
width, height = (256, 256)

# use random size and angle as croped part of image
angle = random.randint(30,85)
unit_h = random.randint(20,80)
lower_bound_w = int(unit_h/math.tan(math.radians(angle)))
if lower_bound_w > 65:
    unit_w = random.randint(lower_bound_w+15, lower_bound_w+75)
else: 
    unit_w = random.randint(lower_bound_w+15, 85)

# width, length, angle of unit cell:
unit_w, unit_h, angle
# Out:
# (79, 32, 32)

# %%
p6m_1 = wp.p6m(image1,unit_w,width,height)

plt.figure(figsize=(5, 5))
plt.imshow(p6m_1)
plt.title('p6m_1 symmetry Plotting')
# Out:
# Text(0.5, 1.0, 'p6m_1 symmetry Plotting')
